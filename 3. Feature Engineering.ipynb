# %% [markdown]
# ### Feature Engineering
#
# - CountVectorizer Bag of Words
# - TF-IDF (Unigram + Bigram) Term Frequency-Inverse Document Frequency
# - LDA Latent Dirichlet Allocation
# - Word2Vec Word Embeddings
# - BERT Tokenization & CLS Embedding Dynamic Contextual Encoding
